# %% [markdown]
# # Juego Personalizado
# ## Descripción
# Prepárate para adentrarte en una espeluznante llega de desafíos que pondrán tus habilidades de guerrero a prueba.
# Enfréntate a tus enemigos y logra consigue la corona al final del desafió.

# %% [markdown]
# ## Reglas del Juego
# Juega con un dado para moverte por el mapa.
# Para atacar a tus enemigos tira dos dados y el resultado obtenido sera el daño causado a los enemigos. En caso de obtener un numero primo fallaras el golpe y que harás daño tu mismo.
# Cada lanzamiento de dado de ataque es considerado un turno. Por cada turno los enemigos te harán 1 de daño. Excepto el dragon, cada dragon hace 3 de daño cada dos turnos.

# %% [markdown]
# ## Tablero

# %%
print ("--------------------------------------------------------------")
print ("|🌲🌲                         🌲🌲🌲🌲🌲🌲🌲      ->👑<-   🌲🌲")
print ("|🌲🌲              🐉         🌲🌲🌲🌲🌲🌲🌲               🌲🌲")
print ("|🌲🌲                         🌲🌲🌲🌲🌲🌲🌲               🌲🌲")
print ("|🌲🌲      🐉   💎💎💎   🐉  🌲🌲🌲🌲🌲🌲🌲               🌲🌲")
print ("|🌲🌲                         🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲      🌲🌲🌲🌲🌲")
print ("|🌲🌲              🐉         🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲  🐉 🌲🌲🌲🌲🌲")
print ("|🌲🌲    🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲      🌲🌲🌲🌲🌲")
print ("|🌲🌲    🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲      🌲🌲🌲🌲🌲")
print ("|🌲🌲    🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲      🌲🌲🌲🌲🌲🌲")
print ("|🌲🌲    🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲      🌲🌲🌲🌲🌲🌲🌲")
print ("|🌲🌲    🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲👺👺 🌲🌲🌲🌲🌲🌲🌲")
print ("|🌲🌲    🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲       🌲🌲🌲🌲🌲🌲🌲")
print ("|🌲🌲    👺👺               👺👺                           🎪🌲")
print ("|🌲🌲    🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲      🌲🌲🌲🌲🌲🌲🌲")
print ("|🌲🌲    🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲      🌲🌲🌲🌲🌲🌲🌲")
print ("|🌲🌲    🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲      🌲🌲🌲🌲🌲🌲🌲")
print ("|🌲🌲    🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲 👹👹 🌲🌲🌲🌲🌲🌲🌲")
print ("|🌲🌲👺👺            🤺<-YOU                 👹👹        💰💰 🌲")
print ("|🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲 🏕 🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲")
print ("--------------------------------------------------------------")
# Out:
# --------------------------------------------------------------
# |🌲🌲                         🌲🌲🌲🌲🌲🌲🌲      ->👑<-   🌲🌲
# |🌲🌲              🐉         🌲🌲🌲🌲🌲🌲🌲               🌲🌲
# |🌲🌲                         🌲🌲🌲🌲🌲🌲🌲               🌲🌲
# |🌲🌲      🐉   💎💎💎   🐉  🌲🌲🌲🌲🌲🌲🌲               🌲🌲
# |🌲🌲                         🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲      🌲🌲🌲🌲🌲
# |🌲🌲              🐉         🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲  🐉 🌲🌲🌲🌲🌲
# |🌲🌲    🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲      🌲🌲🌲🌲🌲
# |🌲🌲    🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲      🌲🌲🌲🌲🌲
# |🌲🌲    🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲      🌲🌲🌲🌲🌲🌲
# |🌲🌲    🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲      🌲🌲🌲🌲🌲🌲🌲
# |🌲🌲    🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲👺👺 🌲🌲🌲🌲🌲🌲🌲
# |🌲🌲    🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲       🌲🌲🌲🌲🌲🌲🌲
# |🌲🌲    👺👺               👺👺                           🎪🌲
# |🌲🌲    🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲      🌲🌲🌲🌲🌲🌲🌲
# |🌲🌲    🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲      🌲🌲🌲🌲🌲🌲🌲
# |🌲🌲    🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲      🌲🌲🌲🌲🌲🌲🌲
# |🌲🌲    🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲 👹👹 🌲🌲🌲🌲🌲🌲🌲
# |🌲🌲👺👺            🤺<-YOU                 👹👹        💰💰 🌲
# |🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲 🏕 🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲
# ...

# %% [markdown]
# ## Piezas

# %%
print("PERSONAJE:")
print ("""
────────▄▄▄▄▄▄▄▄▄
────────▌▐░▀░▀░▀▐
────────▌░▌░░░░░▐
────────▌░░░░░░░▐
────────▄▄▄▄▄▄▄▄▄
──▄▀▀▀▀▀▌▄█▄░▄█▄▐▀▀▀▀▀▄
─█▒▒▒▒▒▐░░░░▄░░░░▌▒▒▒▒▒█
▐▒▒▒▒▒▒▒▌░░░░░░░▐▒▒▒▒▒▒▒▌
▐▒▒▒▒▒▒▒█░▀▀▀▀▀░█▒▒▒▒▒▒▒▌
▐▒▒▒▒▒▒▒▒█▄▄▄▄▄█▒▒▒▒▒▒▒▒▌
▐▒▒▒▒▐▒▒▒▒▒▒▒▒▒▒▒▒▐▒▒▒▒▒▌
▐▒▒▒▒▒█▒▒▒▒▒▒▒▒▒▒▒█▒▒▒▒▒▌
▐▒▒▒▒▒▐▒▒▒▒▒▒▒▒▒▒▒▌▒▒▒▒▒▌
▐▒▒▒▒▒▒▌▒▒▒▒▒▒▒▒▒▐▒▒▒▒▒▒▌
▐▒▒▒▒▒▒▌▄▄▄▄▄▄▄▄▄▐▒▒▒▒▒▒▌
▐▄▄▄▄▄▄▌▌███████▌▐▄▄▄▄▄▄▌
─█▀▀▀▀█─▌███▌███▌─█▀▀▀▀█
─▐░░░░▌─▌███▌███▌─▐░░░░▌
──▀▀▀▀──▌███▌███▌──▀▀▀▀
────────▌███▌███▌
────────▌███▌███▌
──────▐▀▀▀██▌█▀▀▀▌
▒▒▒▒▒▒▐▄▄▄▄▄▄▄▄▄▄▌▒▒▒▒▒▒▒
""")
# Out:
# PERSONAJE:
#
# ────────▄▄▄▄▄▄▄▄▄
# ────────▌▐░▀░▀░▀▐
# ────────▌░▌░░░░░▐
# ────────▌░░░░░░░▐
# ────────▄▄▄▄▄▄▄▄▄
# ──▄▀▀▀▀▀▌▄█▄░▄█▄▐▀▀▀▀▀▄
# ─█▒▒▒▒▒▐░░░░▄░░░░▌▒▒▒▒▒█
# ▐▒▒▒▒▒▒▒▌░░░░░░░▐▒▒▒▒▒▒▒▌
# ▐▒▒▒▒▒▒▒█░▀▀▀▀▀░█▒▒▒▒▒▒▒▌
# ▐▒▒▒▒▒▒▒▒█▄▄▄▄▄█▒▒▒▒▒▒▒▒▌
# ▐▒▒▒▒▐▒▒▒▒▒▒▒▒▒▒▒▒▐▒▒▒▒▒▌
# ▐▒▒▒▒▒█▒▒▒▒▒▒▒▒▒▒▒█▒▒▒▒▒▌
# ▐▒▒▒▒▒▐▒▒▒▒▒▒▒▒▒▒▒▌▒▒▒▒▒▌
# ▐▒▒▒▒▒▒▌▒▒▒▒▒▒▒▒▒▐▒▒▒▒▒▒▌
# ▐▒▒▒▒▒▒▌▄▄▄▄▄▄▄▄▄▐▒▒▒▒▒▒▌
# ▐▄▄▄▄▄▄▌▌███████▌▐▄▄▄▄▄▄▌
# ─█▀▀▀▀█─▌███▌███▌─█▀▀▀▀█
# ─▐░░░░▌─▌███▌███▌─▐░░░░▌
# ──▀▀▀▀──▌███▌███▌──▀▀▀▀
# ────────▌███▌███▌
# ────────▌███▌███▌
# ──────▐▀▀▀██▌█▀▀▀▌
# ▒▒▒▒▒▒▐▄▄▄▄▄▄▄▄▄▄▌▒▒▒▒▒▒▒
#
# 1

# %%
print("ENEMIGO 1: ")
print ("""
▒▒▒▒▒▒▒▒▄▄▄▄▄▄▄▄▒▒▒▒▒▒
▒▒█▒▒▒▄██████████▄▒▒▒▒
▒█▐▒▒▒████████████▒▒▒▒
▒▌▐▒▒██▄▀██████▀▄██▒▒▒
▐┼▐▒▒██▄▄▄▄██▄▄▄▄██▒▒▒
▐┼▐▒▒██████████████▒▒▒
▐▄▐████─▀▐▐▀█─█─▌▐██▄▒
▒▒█████──────────▐███▌
▒▒█▀▀██▄█─▄───▐─▄███▀▒
▒▒█▒▒███████▄██████▒▒▒
▒▒▒▒▒██████████████▒▒▒
▒▒▒▒▒█████████▐▌██▌▒▒▒
▒▒▒▒▒▐▀▐▒▌▀█▀▒▐▒█▒▒▒▒▒
▒▒▒▒▒▒▒▒▒▒▒▐▒▒▒▒▌▒▒▒▒▒
""")
# Out:
# ENEMIGO 1:
#
# ▒▒▒▒▒▒▒▒▄▄▄▄▄▄▄▄▒▒▒▒▒▒
# ▒▒█▒▒▒▄██████████▄▒▒▒▒
# ▒█▐▒▒▒████████████▒▒▒▒
# ▒▌▐▒▒██▄▀██████▀▄██▒▒▒
# ▐┼▐▒▒██▄▄▄▄██▄▄▄▄██▒▒▒
# ▐┼▐▒▒██████████████▒▒▒
# ▐▄▐████─▀▐▐▀█─█─▌▐██▄▒
# ▒▒█████──────────▐███▌
# ▒▒█▀▀██▄█─▄───▐─▄███▀▒
# ▒▒█▒▒███████▄██████▒▒▒
# ▒▒▒▒▒██████████████▒▒▒
# ▒▒▒▒▒█████████▐▌██▌▒▒▒
# ▒▒▒▒▒▐▀▐▒▌▀█▀▒▐▒█▒▒▒▒▒
# ▒▒▒▒▒▒▒▒▒▒▒▐▒▒▒▒▌▒▒▒▒▒

# %%
print("ENEMIGO 2: ")
print ("""
░░░░░░░░░░░║
░░▄█▀▄░░░░░║░░░░░░▄▀▄▄
░░░░░░▀▄░░░║░░░░▄▀
░▄▄▄░░░░█▄▄▄▄▄▄█░░░░▄▄▄
▀░░░▀█░█▀░░▐▌░░▀█░█▀░░░▀
░░░░░░██░░▀▐▌▀░░██
░▄█▀▀▀████████████▀▀▀█
█░░░░░░██████████░░░░░▀▄
█▄░░░█▀░░▀▀▀▀▀▀░░▀█░░░▄█
░▀█░░░█░░░░░░░░░░█░░░█▀
""")
# Out:
# ENEMIGO 2:
#
# ░░░░░░░░░░░║
# ░░▄█▀▄░░░░░║░░░░░░▄▀▄▄
# ░░░░░░▀▄░░░║░░░░▄▀
# ░▄▄▄░░░░█▄▄▄▄▄▄█░░░░▄▄▄
# ▀░░░▀█░█▀░░▐▌░░▀█░█▀░░░▀
# ░░░░░░██░░▀▐▌▀░░██
# ░▄█▀▀▀████████████▀▀▀█
# █░░░░░░██████████░░░░░▀▄
# █▄░░░█▀░░▀▀▀▀▀▀░░▀█░░░▄█
# ░▀█░░░█░░░░░░░░░░█░░░█▀
